# %% [markdown]
# # Pandas

# %% [markdown]
# # file Read Write operation

# %%
import numpy as np
import pandas as pd
np.set_printoptions(precision=4)

# %%
import pandas as pd

draft1 = pd.read_csv('ex1.csv')    # Supply the file name (path)
#draft1 = pd.read_csv('D:\Phyton basic\ineuran\pands\code_pandas1\examplesex1.csv')
#draft1.head(100)  
#draft1.tail(3)  

type(draft1)
# Out:
# pandas.core.frame.DataFrame

# %%
draft2 = pd.read_table('tab.tsv')  # Read a tsv into a DataFrame

draft2.head(1)
# Out:
#    ID  Name login
# 0   1  Siva  Siva

# %%
df = pd.read_csv('ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table('ex1.csv', sep=',')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('ex1.csv', header=None)
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo
# 4  7   6   6  17     Siva
# 5  7   7   7  47      Mag
# 6  4   7   7   7     Hari

# %%
df =pd.read_csv('ex1.csv', names=['ID','SEc_ID', 'b', 'c', 'HI', 'DEtail'])
df
# Out:
#   ID SEc_ID   b   c       HI  DEtail
# 0  a      b   c   d  message     NaN
# 1  1      2   3   4    hello     NaN
# 2  5      6   7   8    world     NaN
# 3  9     10  11  12      foo     NaN
# 4  7      6   6  17     Siva     NaN
# 5  7      7   7  47      Mag     NaN
# 6  4      7   7   7     Hari     NaN

# %%
# !cat /Users/sudhanshukumar/Downloads/examples/csv_mindex.csv
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
parsed = pd.read_csv('csv_mindex.csv')
parsed
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
parsed = pd.read_csv('csv_mindex.csv',
                     index_col=['key1', 'key2'])
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
pd.read_csv('ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
##!cat /Users/sudhanshukumar/Downloads/examples/ex4.csv
pd.read_csv('ex4.csv', skiprows=[0, 2, 3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result = pd.read_csv('ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
##!cat /Users/sudhanshukumar/Downloads/examples/ex5.csv
result = pd.read_csv('ex5.csv')
result
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result = pd.read_csv('ex5.csv', na_values=['world'])
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8     NaN
# 2     three  9  10  11.0  12     foo

# %%
draft3 = pd.read_excel('ex1.xlsx',sheet_name= 'ex2') # Name of sheet to read from

draft3.head(6)
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"
Url1="https://www.asm.com"
BB_data = pd.read_html(Url1)         # Read data from the specified url
BB_data
#BB_data[0].ix[:, 0:20].head(5)      # Check 5 rows (10 columns only)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-acdb19bd8e19> in <module>
#       1 url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"
#       2 Url1="https://www.asm.com"
# ----> 3 BB_data = pd.read_html(Url1)         # Read data from the specified url
#       4 BB_data
#       5 #BB_data[0].ix[:, 0:20].head(5)      # Check 5 rows (10 columns only)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ...

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')

# %%
titanic_train.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
series=titanic_train["Name"].head()
type(series)
# Out:
# pandas.core.series.Series

# %%
d=titanic_train[["Name","Pclass"]].head()
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('ex6.csv')
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv('ex6.csv', nrows=5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
chunk = pd.read_csv('ex6.csv', chunksize=1000)
chunk

# %% [markdown]
# Writing Data to Text Format

# %%
import pandas as pd
data = pd.read_csv('ex5.csv')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv('outtoday.csv')
#!cat /Users/sudhanshukumar/Downloads/out.csv

# %%
import sys
data.to_csv('outtoday.csv', sep='@')

# %%
data.to_csv(sys.stdout, na_rep='NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv('out2.csv', index=False, header=False)

# %%
data.to_csv('out3.csv', index=False, columns=['a', 'b', 'c'])

# %%
import numpy as np
linp=(np.arange(6))
linp

li=(range(6))
li
# Out:
# range(0, 6)

# %%
dates = pd.date_range('1/1/2000', periods=7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('tseries.csv')
#!cat /Users/sudhanshukumar/Downloads/examples/tseries.csv

# %% [markdown]
# Working with Delimited Formats

# %%
import csv
f = open('ex7.csv')

reader = csv.reader(f)
reader

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open('ex7.csv') as f: 
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
header
# Out:
# ['a', 'b', 'c']

# %%
values
# Out:
# [['1', '2', '3'], ['1', '2', '3']]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %% [markdown]
# JSON Data

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]},
{"name": "Sica", "age": 22,
               "pets": ["Cat", "Dog", "Pig"]}

                  
]
}
"""

# %%
import json
result = json.loads(obj)
type(result)
# Out:
# dict

# %%
asjson = json.dumps(result)
asjson
type(asjson)
# Out:
# str

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age','pets'])
siblings
# Out:
#     name  age                    pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   38  [Sixes, Stache, Cisco]
# 2   Sica   22         [Cat, Dog, Pig]

# %%
#!cat /Users/sudhanshukumar/Downloads/examples/example.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
#  {"a": 4, "b": 5, "c": 6},
#  {"a": 7, "b": 8, "c": 9}]

# %%
data = pd.read_json('example.json')
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data.to_json())
print(data.to_json(orient='records'))
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# XML and HTML: Web Scraping

# %%
tables = pd.read_html('fdic_failed_bank_list.html')
len(tables)
failures = tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
tables[0]
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
close_timestamps = pd.to_datetime(failures['Updated Date'])
close_timestamps.dt.year.value_counts()
#close_timestamps
# Out:
# 2012    227
# 2014    109
# 2016     91
# 2015     66
# 2013     36
# 2008      6
# 2005      5
# 2004      2
# 2003      2
# 2010      1
# 2006      1
# 2002      1
# Name: Updated Date, dtype: int64

# %% [markdown]
# # Binary Data Formats

# %%
frame = pd.read_csv('ex1.csv')
frame
frame.to_pickle('frame_pickle')

# %%
pd.read_pickle('frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo
# 3  7   6   6  17    Siva
# 4  7   7   7  47     Mag
# 5  4   7   7   7    Hari

# %%
# !rm /Users/sudhanshukumar/Downloads/examples/frame_pickle
# Out:
# rm: /Users/sudhanshukumar/Downloads/examples/frame_pickle: No such file or directory

# %% [markdown]
# Using HDF5 Format

# %%
np.random.randn(100)
# Out:
# array([ 0.61953219,  0.08520076, -1.31318297,  0.5760812 ,  0.23540279,
#         0.90156174,  0.32499098, -0.35454035,  0.27371562, -0.6637264 ,
#         0.05081323,  1.5685329 , -0.60490882, -0.61787322, -0.96778058,
#        -0.34994615,  0.55728675,  0.45971484,  0.37379682, -0.82073231,
#         0.20233982, -0.95631674,  0.79952574,  1.03832189, -2.31718771,
#        -0.36541085,  0.58297106,  0.09851554, -0.65305357,  1.30889759,
#         0.29734407,  0.01529825,  0.64962733,  0.56805388, -0.80163164,
#         0.14339135, -0.23411717,  1.91419901, -0.96137446, -0.50529332,
#         0.71099343,  0.25856204, -0.07331116,  0.2259462 , -0.06954886,
#         1.03380752, -0.77762891,  0.78392943, -1.34251923, -0.031546  ,
#         0.4391432 , -0.77687125, -0.39039686, -0.15139347,  0.68157647,
#         0.04182212, -0.02305767,  1.28971696, -0.16505518,  1.58339968,
#        -0.13906765,  0.54775251,  0.00907085,  0.27650805, -1.38880591,
# ...

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0   1.212260
# 1   1.438855
# 2  -0.426525
# 3   2.774679
# 4   1.090206
# ..       ...
# 95  2.261248
# 96 -1.936576
# 97  0.327743
# 98 -0.567130
# 99 -1.563750
#
# [100 rows x 1 columns]

# %%
store.put('obj2', frame, format='table')
store.select('obj2', where=['index >= 10 and index <= 15'])
store.close()

# %%
frame.to_hdf('mydata.h5', 'obj3', format='table')
pd.read_hdf('mydata.h5', 'obj3', where=['index < 5'])
# Out:
#           a
# 0  1.212260
# 1  1.438855
# 2 -0.426525
# 3  2.774679
# 4  1.090206

# %% [markdown]
# # Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[1]['user']
# Out:
# {'login': 'rossbar',
#  'id': 1268991,
#  'node_id': 'MDQ6VXNlcjEyNjg5OTE=',
#  'avatar_url': 'https://avatars2.githubusercontent.com/u/1268991?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rossbar',
#  'html_url': 'https://github.com/rossbar',
#  'followers_url': 'https://api.github.com/users/rossbar/followers',
#  'following_url': 'https://api.github.com/users/rossbar/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rossbar/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rossbar/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rossbar/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rossbar/orgs',
#  'repos_url': 'https://api.github.com/users/rossbar/repos',
#  'events_url': 'https://api.github.com/users/rossbar/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rossbar/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
issues = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    35332           DOC: [Errno 2] No such file or directory
# 1    35331                  BUG: np.argwhere on pandas series
# 2    35330  REF: remove special casing from Index.equals (...
# 3    35326      BUG: multiindex reindex doesn't work properly
# 4    35325  BUG: Combination of groupby.resample.interpola...
# 5    35321        BUG: clip does not accept numpy's arguments
# 6    35320  BUG:New epoch in matplotlib 3.3 causes plottin...
# 7    35318                                    Update multi.py
# 8    35317  DOC: Rst Formatting, make sure continuation pr...
# 9    35315                              DOC: whatsnew for 1.2
# 10   35314  BUG: GroupBy.apply() returns different results...
# 11   35313  ENH: pandas.DataFrame.pivot option to output h...
# 12   35311                          TYP: Add MyPy Error Codes
# 13   35309                      Crashed Worker tracking issue
# ...

# %%
issues = pd.DataFrame(data)
issues
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %% [markdown]
# # Interacting with Databases

# %%
import sqlite3
#connecting with the database.
db = sqlite3.connect("my_database4.db")
# Drop table if it already exist using execute() method.
db.execute("drop table if exists test")
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""
con = sqlite3.connect('mydata2.sqlite')
con.execute(query)
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
#!/usr/bin/python

import sqlite3
#connecting with the database.
db = sqlite3.connect("my_database5.db")
# Drop table if it already exist using execute() method.
db.execute("drop table if exists grades1")
# Create table as per requirement
db.execute("create table grades1(id int, name text, score int)")
#inserting values inside the created table
db.execute("insert into grades1(id, name, score) values(101, 'John',99 )")
db.execute("insert into grades1(id, name, score) values(102, 'Gary',90 )")
db.execute("insert into grades1(id, name, score) values(103, 'James', 80 )")
db.execute("insert into grades1(id, name, score) values(104, 'Cathy', 85 )")
db.execute("insert into grades1(id, name, score) values(105, 'Kris',95 )")

# %%
db.commit()

# %%
results = db.execute("select * from grades1 order by id")
for row in results:
    print((row))
print("-" * 60 )
# Out:
# (101, 'John', 99)
# (102, 'Gary', 90)
# (103, 'James', 80)
# (104, 'Cathy', 85)
# (105, 'Kris', 95)
# ------------------------------------------------------------

# %%
results = db.execute("select * from grades1 where name = 'Gary' ")
for row in results: print(row)
print("-"* 60 )
# Out:
# (102, 'Gary', 90)
# ------------------------------------------------------------

# %%
results = db.execute("select * from grades1 where score >= 90 ")
for row in results:
    print(row)
print("-" * 60 )
# Out:
# (101, 'John', 99)
# (102, 'Gary', 90)
# (105, 'Kris', 95)
# ------------------------------------------------------------

# %%
results = db.execute("select name, score from grades1 order by score desc ")
for row in results:
    print(row)
print("-" * 60 )
# Out:
# ('John', 99)
# ('Kris', 95)
# ('Gary', 90)
# ('Cathy', 85)
# ('James', 80)
# ------------------------------------------------------------

# %%
results = db.execute("select name, score from grades1 order by score")
for row in results:
    print(row)
print("-" * 60 )
# Out:
# ('James', 80)
# ('Cathy', 85)
# ('Gary', 90)
# ('Kris', 95)
# ('John', 99)
# ------------------------------------------------------------

# %%
results = db.execute("select name, score from grades1 order by score")
for row in results:
    print(row)
# Out:
# ('James', 80)
# ('Cathy', 85)
# ('Gary', 90)
# ('Kris', 95)
# ('John', 99)
