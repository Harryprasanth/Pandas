# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
titanic_train.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 146          147         1       3
# 147          148         0       3
# 148          149         0       2
# 149          150         0       2
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 146  Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0      0      0
# 147              Ford, Miss. Robina Maggie "Ruby"  female   9.0      2      2
# 148      Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0      2
# 149             Byles, Rev. Thomas Roussel Davids    male  42.0      0      0
# 150                    Bateman, Rev. Robert James    male  51.0      0      0
# 151             Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                              Meo, Mr. Alfonzo    male  55.5      0      0
# 153               van Billiard, Mr. Austin Blyler    male  40.5      0      2
# 154                         Olsen, Mr. Ole Martin    male   NaN      0      0
# 155                   Williams, Mr. Charles Duane    male  51.0      0      1
#
#           Ticket     Fare Cabin Embarked
# 146       350043   7.7958   NaN        S
# 147   W./C. 6608  34.3750   NaN        S
# 148       230080  26.0000    F2        S
# 149       244310  13.0000   NaN        S
# 150  S.O.P. 1166  12.5250   NaN        S
# 151       113776  66.6000    C2        S
# 152   A.5. 11206   8.0500   NaN        S
# 153     A/5. 851  14.5000   NaN        S
# 154    Fa 265302   7.3125   NaN        S
# 155     PC 17597  61.3792   NaN        C

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes == "object"
a = titanic_train.dtypes[titanic_train.dtypes == "object"].index
a
titanic_train[a].describe()
# Out:
#                             Name   Sex   Ticket        Cabin Embarked
# count                        156   156      156           31      155
# unique                       156     2      145           28        3
# top     Moubarek, Master. Gerios  male  CA 2144  C23 C25 C27        S
# freq                           1   100        2            2      110

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train.dtypes[titanic_train.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train.dtypes[titanic_train.dtypes == "object"]


titanic_train.dtypes[titanic_train.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train.dtypes[titanic_train.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
list_col = titanic_train.dtypes[titanic_train.dtypes == "object"].index
titanic_train[list_col].describe()
# Out:
#                                 Name   Sex  Ticket Cabin Embarked
# count                            156   156     156    31      155
# unique                           156     2     145    28        3
# top     Williams, Mr. Charles Eugene  male  113803  C123        S
# freq                               1   100       2     2      110

# %%
titanic_train[['Name','Sex','Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# 5                                     Moran, Mr. James    male   NaN
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 7                       Palsson, Master. Gosta Leonard    male   2.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# 12                      Saundercock, Mr. William Henry    male  20.0
# 13                         Andersson, Mr. Anders Johan    male  39.0
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                                Rice, Master. Eugene    male   2.0
# 17                        Williams, Mr. Charles Eugene    male   NaN
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19                             Masselmani, Mrs. Fatima  female   NaN
# 20                                Fynney, Mr. Joseph J    male  35.0
# 21                               Beesley, Mr. Lawrence    male  34.0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0
# 23                        Sloper, Mr. William Thompson    male  28.0
# 24                       Palsson, Miss. Torborg Danira  female   8.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 26                             Emir, Mr. Farred Chehab    male   NaN
# 27                      Fortune, Mr. Charles Alexander    male  19.0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN
# 29                                 Todoroff, Mr. Lalio    male   NaN
# ..                                                 ...     ...   ...
# 126                                McMahon, Mr. Martin    male   NaN
# 127                          Madsen, Mr. Fridtjof Arne    male  24.0
# 128                                  Peter, Miss. Anna  female   NaN
# 129                                 Ekstrom, Mr. Johan    male  45.0
# 130                               Drazenoic, Mr. Jozef    male  33.0
# 131                     Coelho, Mr. Domingos Fernandeo    male  20.0
# 132     Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
# 133      Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 134                     Sobey, Mr. Samuel James Hayden    male  25.0
# 135                                 Richard, Mr. Emile    male  23.0
# 136                       Newsom, Miss. Helen Monypeny  female  19.0
# 137                        Futrelle, Mr. Jacques Heath    male  37.0
# 138                                Osen, Mr. Olaf Elon    male  16.0
# 139                                 Giglio, Mr. Victor    male  24.0
# 140                      Boulos, Mrs. Joseph (Sultana)  female   NaN
# 141                           Nysten, Miss. Anna Sofia  female  22.0
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.0
# 143                                Burke, Mr. Jeremiah    male  19.0
# 144                         Andrew, Mr. Edgardo Samuel    male  18.0
# 145                       Nicholls, Mr. Joseph Charles    male  19.0
# 146       Andersson, Mr. August Edvard ("Wennerstrom")    male  27.0
# 147                   Ford, Miss. Robina Maggie "Ruby"  female   9.0
# 148           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5
# 149                  Byles, Rev. Thomas Roussel Davids    male  42.0
# 150                         Bateman, Rev. Robert James    male  51.0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0
# 152                                   Meo, Mr. Alfonzo    male  55.5
# 153                    van Billiard, Mr. Austin Blyler    male  40.5
# 154                              Olsen, Mr. Ole Martin    male   NaN
# 155                        Williams, Mr. Charles Duane    male  51.0
#
# [156 rows x 3 columns]

# %%
titanic_train["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
sorted(titanic_train["Name"])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
#  'Christmann, Mr. Emil',
#  'Chronopoulos, Mr. Apostolos',
#  'Coelho, Mr. Domingos Fernandeo',
#  'Connors, Mr. Patrick',
#  'Coxon, Mr. Daniel',
#  'Crease, Mr. Ernest James',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Dean, Mr. Bertram Frank',
#  'Devaney, Miss. Margaret Delia',
#  'Doling, Mrs. John T (Ada Julia Bone)',
#  'Dowdell, Miss. Elizabeth',
#  'Drazenoic, Mr. Jozef',
#  'Ekstrom, Mr. Johan',
#  'Emir, Mr. Farred Chehab',
#  'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#  'Ford, Miss. Robina Maggie "Ruby"',
#  'Ford, Mr. William Neal',
#  'Fortune, Miss. Mabel Helen',
#  'Fortune, Mr. Charles Alexander',
#  'Futrelle, Mr. Jacques Heath',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Fynney, Mr. Joseph J',
#  'Giglio, Mr. Victor',
#  'Glynn, Miss. Mary Agatha',
#  'Goldschmidt, Mr. George B',
#  'Goodwin, Master. William Frederick',
#  'Goodwin, Miss. Lillian Amy',
#  'Greenfield, Mr. William Bertram',
#  'Gustafsson, Mr. Anders Vilhelm',
#  'Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)',
#  'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#  'Harris, Mr. Henry Birkhardt',
#  'Heikkinen, Miss. Laina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Hickman, Mr. Stanley George',
#  'Holverson, Mr. Alexander Oskar',
#  'Hood, Mr. Ambrose Jr',
#  'Icard, Miss. Amelie',
#  'Ilett, Miss. Bertha',
#  'Jenkin, Mr. Stephen Curnow',
#  'Johansson, Mr. Gustaf Joel',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Jussila, Miss. Katriina',
#  'Kantor, Mr. Sinai',
#  'Kink, Mr. Vincenz',
#  'Kraeff, Mr. Theodor',
#  'Laroche, Miss. Simonne Marie Anne Andree',
#  'Lennon, Mr. Denis',
#  'Madsen, Mr. Fridtjof Arne',
#  'Mamee, Mr. Hanna',
#  'Masselmani, Mrs. Fatima',
#  'McCarthy, Mr. Timothy J',
#  'McDermott, Miss. Brigdet Delia',
#  'McGowan, Miss. Anna "Annie"',
#  'McMahon, Mr. Martin',
#  'Meo, Mr. Alfonzo',
#  'Meyer, Mr. Edgar Joseph',
#  'Mionoff, Mr. Stoytcho',
#  'Moen, Mr. Sigurd Hansen',
#  'Moore, Mr. Leonard Charles',
#  'Moran, Miss. Bertha',
#  'Moran, Mr. James',
#  'Moss, Mr. Albert Johan',
#  'Moubarek, Master. Gerios',
#  'Moutal, Mr. Rahamin Haim',
#  'Nasser, Mr. Nicholas',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Navratil, Mr. Michel ("Louis M Hoffman")',
#  'Newsom, Miss. Helen Monypeny',
#  'Nicholls, Mr. Joseph Charles',
#  'Nicola-Yarred, Master. Elias',
#  'Nicola-Yarred, Miss. Jamila',
#  'Nosworthy, Mr. Richard Cater',
#  'Novel, Mr. Mansouer',
#  'Nye, Mrs. (Elizabeth Ramell)',
#  'Nysten, Miss. Anna Sofia',
#  "O'Driscoll, Miss. Bridget",
#  'O\'Dwyer, Miss. Ellen "Nellie"',
#  'Olsen, Mr. Ole Martin',
#  'Osen, Mr. Olaf Elon',
#  'Ostby, Mr. Engelhart Cornelius',
#  'Palsson, Master. Gosta Leonard',
#  'Palsson, Miss. Torborg Danira',
#  'Panula, Master. Juha Niilo',
#  'Pears, Mrs. Thomas (Edith Wearne)',
#  'Pekoniemi, Mr. Edvard',
#  'Peter, Miss. Anna',
#  'Petranec, Miss. Matilda',
#  'Petroff, Mr. Pastcho ("Pentcho")',
#  'Porter, Mr. Walter Chamberlain',
#  'Rekic, Mr. Tido',
#  'Rice, Master. Eugene',
#  'Richard, Mr. Emile',
#  'Robins, Mrs. Alexander A (Grace Charity Laury)',
#  'Rogers, Mr. William John',
#  'Rugg, Miss. Emily',
#  'Salkjelsvik, Miss. Anna Kristine',
#  'Samaan, Mr. Youssef',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Saundercock, Mr. William Henry',
#  'Sheerlinck, Mr. Jan Baptist',
#  'Shorney, Mr. Charles Joseph',
#  'Sirayanian, Mr. Orsen',
#  'Skoog, Master. Harald',
#  'Slocovski, Mr. Selman Francis',
#  'Sloper, Mr. William Thompson',
#  'Sobey, Mr. Samuel James Hayden',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Staneff, Mr. Ivan',
#  'Stewart, Mr. Albert A',
#  'Todoroff, Mr. Lalio',
#  'Turpin, Mr. William John Robert',
#  'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#  'Uruchurtu, Don. Manuel E',
#  'Vander Planke, Miss. Augusta Maria',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Waelens, Mr. Achille',
#  'Webber, Miss. Susan',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'West, Miss. Constance Mirium',
#  'Wheadon, Mr. Edward H',
#  'White, Mr. Percival Wayland',
#  'White, Mr. Richard Frasar',
#  'Williams, Mr. Charles Duane',
#  'Williams, Mr. Charles Eugene',
#  'Woolner, Mr. Hugh',
#  'Zabour, Miss. Hileni',
#  'van Billiard, Mr. Austin Blyler']

# %%
sorted(titanic_train["Name"])[5:20:2]# Check the first 15 sorted names
# Out:
# ['Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andrew, Mr. Edgardo Samuel',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Bateman, Rev. Robert James',
#  'Beesley, Mr. Lawrence',
#  'Bonnell, Miss. Elizabeth',
#  'Braund, Mr. Owen Harris']

# %%
titanic_train["Name"].describe()
# Out:
# count                              156
# unique                             156
# top       Williams, Mr. Charles Eugene
# freq                                 1
# Name: Name, dtype: object

# %%
titanic_train[["Ticket"]][4:9]
# Out:
#    Ticket
# 4  373450
# 5  330877
# 6   17463
# 7  349909
# 8  347742

# %%
titanic_train["Ticket"].describe()
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train["Name"]="Hari"

# %%
titanic_train.head(100)
# Out:
#     PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0             1         0       3  Hari    male  22.0      1      0
# 1             2         1       1  Hari  female  38.0      1      0
# 2             3         1       3  Hari  female  26.0      0      0
# 3             4         1       1  Hari  female  35.0      1      0
# 4             5         0       3  Hari    male  35.0      0      0
# ..          ...       ...     ...   ...     ...   ...    ...    ...
# 95           96         0       3  Hari    male   NaN      0      0
# 96           97         0       1  Hari    male  71.0      0      0
# 97           98         1       1  Hari    male  23.0      0      1
# 98           99         1       2  Hari  female  34.0      0      1
# 99          100         0       2  Hari    male  34.0      1      0
#
#               Ticket     Fare    Cabin Embarked
# 0          A/5 21171   7.2500      NaN        S
# 1           PC 17599  71.2833      C85        C
# 2   STON/O2. 3101282   7.9250      NaN        S
# 3             113803  53.1000     C123        S
# 4             373450   8.0500      NaN        S
# ..               ...      ...      ...      ...
# 95            374910   8.0500      NaN        S
# 96          PC 17754  34.6542       A5        C
# 97          PC 17759  63.3583  D10 D12        C
# 98            231919  23.0000      NaN        S
# 99            244367  26.0000      NaN        S
#
# [100 rows x 12 columns]

# %%
titanic_train["Cabin"][0:15]       # Check the first 15 tickets
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3     C123
# 4      NaN
# 5      NaN
# 6      E46
# 7      NaN
# 8      NaN
# 9      NaN
# 10      G6
# 11    C103
# 12     NaN
# 13     NaN
# 14     NaN
# Name: Cabin, dtype: object

# %%
titanic_train.dtypes# Check number of unique cabins
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# test             int64
# dtype: object

# %%
titanic_train["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 126    0
# 127    1
# 128    1
# 129    0
# 130    0
# 131    0
# 132    0
# 133    1
# 134    0
# 135    0
# 136    1
# 137    0
# 138    0
# 139    0
# 140    0
# 141    1
# 142    1
# 143    0
# 144    0
# 145    0
# 146    1
# 147    0
# 148    0
# 149    0
# 150    0
# 151    1
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Survived, Length: 156, dtype: int64

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'test'],
#       dtype='object')

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare   test
# count  156.000000  156.000000  156.0
# mean     0.397436   28.109587    0.0
# std      0.870146   39.401047    0.0
# min      0.000000    6.750000    0.0
# 25%      0.000000    8.003150    0.0
# 50%      0.000000   14.454200    0.0
# 75%      0.000000   30.371850    0.0
# max      5.000000  263.000000    0.0

# %%
new_Pclass = pd.Categorical(titanic_train["Survived"])

new_Pclass
# Out:
# [0, 1, 1, 1, 0, ..., 1, 0, 0, 0, 0]
# Length: 156
# Categories (2, int64): [0, 1]

# %%
new_Pclass = pd.Categorical(titanic_train["Pclass"])
new_Pclass
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
titanic_train["Cabin"].unique()   # Check unique cabins
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
import numpy as np 
char_cabin = titanic_train["Cabin"].astype(str) # Convert data to str
char_cabin
# Out:
# 0       nan
# 1       C85
# 2       nan
# 3      C123
# 4       nan
#        ...
# 151      C2
# 152     nan
# 153     nan
# 154     nan
# 155     nan
# Name: Cabin, Length: 156, dtype: object

# %%
import numpy as np 
char_cabin = titanic_train["Cabin"].astype(str) # Convert data to str

new_Cabin = [cabin[0] for cabin in char_cabin] # Take first letter

new_Cabin = pd.Categorical(new_Cabin)
#new_Cabin
new_Cabin
# Out:
# [n, C, n, C, n, ..., C, n, n, n, n]
# Length: 156
# Categories (8, object): [A, B, C, D, E, F, G, n]

# %%
titanic_train["Cabin1"] = new_Cabin
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3  Hari    male  22.0      1      0
# 1            2         1       1  Hari  female  38.0      1      0
# 2            3         1       3  Hari  female  26.0      0      0
# 3            4         1       1  Hari  female  35.0      1      0
# 4            5         0       3  Hari    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked Cabin1
# 0         A/5 21171   7.2500   NaN        S      n
# 1          PC 17599  71.2833   C85        C      C
# 2  STON/O2. 3101282   7.9250   NaN        S      n
# 3            113803  53.1000  C123        S      C
# 4            373450   8.0500   NaN        S      n

# %%
titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 126     True
# 127    False
# 128     True
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140     True
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
missing = np.where(titanic_train["Age"].isnull() == True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
np.where(titanic_train["Fare"]=max(titanic_train["Fare"]))
# Out:
#   File "<ipython-input-37-5268125faf28>", line 1
#     np.where(titanic_train["Fare"]=max(titanic_train["Fare"]))
#             ^
# SyntaxError: keyword can't be an expression

# %%
titanic_train.iloc[np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))]
# Out:
#     PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch Ticket  \
# 27           28         0       1  Hari    male  19.0      3      2  19950
# 88           89         1       1  Hari  female  23.0      3      2  19950
#
#      Fare        Cabin Embarked Cabin1
# 27  263.0  C23 C25 C27        S      C
# 88  263.0  C23 C25 C27        S      C

# %%
np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))
# Out:
# (array([27, 88]),)

# %%
len(missing[0])
# Out:
# 30

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]
titanic_train["Family"]
most_family = np.where(titanic_train["Family"] == max(titanic_train["Family"]))
most_family
# Out:
# (array([59, 71], dtype=int64),)

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]

most_family = np.where(titanic_train["Family"] == max(titanic_train["Family"]))
most_family
titanic_train.iloc[most_family]
# Out:
#     PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch   Ticket  \
# 59           60         0       3  Hari    male  11.0      5      2  CA 2144
# 71           72         0       3  Hari  female  16.0      5      2  CA 2144
#
#     Fare Cabin Embarked Cabin1  Family
# 59  46.9   NaN        S      n       7
# 71  46.9   NaN        S      n       7

# %%
import pandas as pd
import numpy as np
d = {'a':"kjhk",'b':20,'c':30}
d.items
pd.DataFrame(d,index = ['a','b','c'])
# Out:
#       a   b   c
# a  kjhk  20  30
# b  kjhk  20  30
# c  kjhk  20  30

# %%
from numpy.random import randn as rn
#np.random.seed(101)
matrix_data = rn(5,4)
row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']

df = pd.DataFrame(matrix_data,row_labels,column_headings)
#print("\nThe data frame looks like\n",'-'*45, sep='')
df
# Out:
#           W         X         Y         Z
# A  0.841192  0.662334  0.616624 -0.730156
# B  0.245374  0.554750  1.397740 -1.202630
# C -2.106038 -1.422779  0.477050 -0.999455
# D  0.375482 -0.464899  0.968338  0.772466
# E  2.067285 -1.349534 -2.438901  0.321404

# %%
df.iloc[2]
# Out:
# W   -2.106038
# X   -1.422779
# Y    0.477050
# Z   -0.999455
# Name: C, dtype: float64

# %%
print("\nThe 'X' column accessed by DOT method (NOT recommended)\n",'-'*55, sep='')
print(df["X"])
# Out:
# The 'X' column accessed by DOT method (NOT recommended)
# -------------------------------------------------------
# A    0.662334
# B    0.554750
# C   -1.422779
# D   -0.464899
# E   -1.349534
# Name: X, dtype: float64

# %%
print("\nA column is created by assigning it in relation to an existing column\n",'-'*75, sep='')
df['New'] = df['X']+df['Z']
df['New (Sum of X and Z)'] = df['X']*df['Z']
print(df)
# Out:
# A column is created by assigning it in relation to an existing column
# ---------------------------------------------------------------------------
#           W         X         Y         Z       New  New (Sum of X and Z)
# A  0.841192  0.662334  0.616624 -0.730156 -0.067822             -0.483608
# B  0.245374  0.554750  1.397740 -1.202630 -0.647881             -0.667159
# C -2.106038 -1.422779  0.477050 -0.999455 -2.422234              1.422003
# D  0.375482 -0.464899  0.968338  0.772466  0.307566             -0.359119
# E  2.067285 -1.349534 -2.438901  0.321404 -1.028130             -0.433745

# %%
df
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)
# A  0.841192  0.662334  0.616624 -0.730156 -0.067822             -0.483608
# B  0.245374  0.554750  1.397740 -1.202630 -0.647881             -0.667159
# C -2.106038 -1.422779  0.477050 -0.999455 -2.422234              1.422003
# D  0.375482 -0.464899  0.968338  0.772466  0.307566             -0.359119
# E  2.067285 -1.349534 -2.438901  0.321404 -1.028130             -0.433745

# %%
print("\nA column is dropped by using df.drop() method\n",'-'*55, sep=' ')
df.drop("W",axis=1) # Notice the axis=1 option, axis = 0 is default, so one has to change it to 1
# Out:
# A column is dropped by using df.drop() method
#  -------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-914ae46838f9> in <module>
#       1 print("\nA column is dropped by using df.drop() method\n",'-'*55, sep=' ')
# ----> 2 df.drop("W",axis=1) # Notice the axis=1 option, axis = 0 is default, so one has to change it to 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['W'] not found in axis"

# %%
df
# Out:
#    Age  Height  Weight
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
df1=df.drop('A')
print("\nA row (index) is dropped by using df.drop() method and axis=0\n",'-'*65, sep='')
print(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-866d2ce47bab> in <module>
# ----> 1 df1=df.drop('A')
#       2 print("\nA row (index) is dropped by using df.drop() method and axis=0\n",'-'*65, sep='')
#       3 print(df1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['A'] not found in axis"

# %%
print("\nAn in-place change can be done by making inplace=True in the drop method\n",'-'*75, sep='')
df.drop('New (Sum of X and Z)', axis=1, inplace=True)
print(df)

# %%
### Selecting/indexing Rows
#* Label-based 'loc' method
#* Index (numeric) 'iloc' method
df

# %%
print("\nLabel-based 'loc' method can be used for selecting row(s)\n",'-'*60, sep='')
print("\nSingle row\n")
print(df.iloc[3])

# %%
print("\nMultiple rows\n")
df.loc[['A']]  ---Colum index
print(df["W"]) ---Row Index
#print(df.loc[['B','W']])

# %%
print("\nIndex position based 'iloc' method can be used for selecting row(s)\n",'-'*70, sep='')
print("\nSingle row\n")
print(df.iloc[2])

# %%
print("\nMultiple rows\n")
print(df.iloc[[1,2]])

# %%
#### Subsetting DataFrame

# %%
matrix_data = rn(5,4)
row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']
df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)

# %%
print("\nThe DatFrame\n",'-'*45, sep='')
print(df)

# %%
print("\nElement at row 'B' and column 'Y' is\n") 
print(df.loc[['B','C'],['Y','W']])

# %%
print("\nSubset comprising of rows B and D, and columns W and Y, is\n")
df.iloc[[1,2,3],[0,1]]

# %%
print(df.loc[['B','C'],])

# %%
print("\n")
print(df.loc[['A','B','C']]>0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-0adef0ec0e77> in <module>
#       1 print("\n")
# ----> 2 print(df.loc[['A','B','C']]>0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1951                     raise ValueError("Cannot index with multidimensional key")
#    1952
# -> 1953                 return self._getitem_iterable(key, axis=axis)
#    1954
#    1955             # nested tuple slicing
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1592         else:
#    1593             # A collection of keys
# -> 1594             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1595             return self.obj._reindex_with_indexers(
#    1596                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1652             if not (ax.is_categorical() or ax.is_interval()):
#    1653                 raise KeyError(
# -> 1654                     "Passing list-likes to .loc or [] with any missing labels "
#    1655                     "is no longer supported, see "
#    1656                     "https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"  # noqa:E501
#
# KeyError: 'Passing list-likes to .loc or [] with any missing labels is no longer supported, see https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike'

# %%
booldf = df>0
print("\nDataFrame indexed by boolean dataframe\n",'-'*45, sep='')
print(df[booldf])
# Out:
# DataFrame indexed by boolean dataframe
# ---------------------------------------------
#           W        X         Y         Z       New  New (Sum of X and Z)
# B  0.245374  0.55475  1.397740       NaN       NaN                   NaN
# C       NaN      NaN  0.477050       NaN       NaN              1.422003
# D  0.375482      NaN  0.968338  0.772466  0.307566                   NaN
# E  2.067285      NaN       NaN  0.321404       NaN                   NaN

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']
matrix_data
# Out:
# matrix([[ 22,  66, 140],
#         [ 42,  70, 148],
#         [ 30,  62, 125],
#         [ 35,  68, 160],
#         [ 25,  62, 152]])

# %%
df = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
print("\nA new DataFrame\n",'-'*25, sep='')
print(df)
# Out:
# A new DataFrame
# -------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
df[df['Height']>65]
# Out:
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# D   35      68     160

# %%
print("\nRows with Height > 65 inch\n",'-'*100, sep='')
print(df[df['Height']>65])
# Out:
# Rows with Height > 65 inch
# ----------------------------------------------------------------------------------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# D   35      68     160

# %%
df['Height']>65
# Out:
# A     True
# B     True
# C    False
# D     True
# E    False
# Name: Height, dtype: bool

# %%
booldf1 = df['Height']>65
booldf2 = df['Weight']>145

# %%
print("\nRows with Height > 65 inch and Weight >145 lbs\n",'-'*55, sep='')
print(df[(booldf1) & (booldf2)])
# Out:
# Rows with Height > 65 inch and Weight >145 lbs
# -------------------------------------------------------
#    Age  Height  Weight
# B   42      70     148
# D   35      68     160

# %%
print("\nDataFrame with only Age and Weight columns whose Height > 65 inch\n",'-'*68, sep='')
print(df[booldf1][['Age','Weight']])
# Out:
# DataFrame with only Age and Weight columns whose Height > 65 inch
# --------------------------------------------------------------------
#    Age  Weight
# A   22     140
# B   42     148
# D   35     160

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']

# %%
df
# Out:
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
print("\nAfter resetting index\n",'-'*35, sep='')
print(df.reset_index())
# Out:
# After resetting index
# -----------------------------------
#   index  Age  Height  Weight
# 0     A   22      66     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152

# %%
print("\nAfter resetting index with 'drop' option TRUE\n",'-'*45, sep='')
print(df.reset_index(drop=True))
"Student Teacher Engineer Doctor Nurse".split()
# Out:
# After resetting index with 'drop' option TRUE
# ---------------------------------------------
#    Age  Height  Weight
# 0   22      66     140
# 1   42      70     148
# 2   30      62     125
# 3   35      68     160
# 4   25      62     152
# ['Student', 'Teacher', 'Engineer', 'Doctor', 'Nurse']

# %%
df
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)
# B -0.353145 -1.094828  3.705136 -0.148606 -1.243434              0.162698
# C -2.249747 -0.147924  1.190617  0.195905  0.047981             -0.028979
# D -0.605244  0.872743  0.777672 -0.333161  0.539582             -0.290764
# E -0.709008  0.225959  0.135471  0.150424  0.376383              0.033990

# %%
print("\nAdding a new column 'Profession'\n",'-'*45, sep='')
df['Profession'] = "Student Teacher Engineer Doctor".split()
print(df)
# Out:
# Adding a new column 'Profession'
# ---------------------------------------------
#           W         X         Y         Z       New  New (Sum of X and Z)  \
# B -0.353145 -1.094828  3.705136 -0.148606 -1.243434              0.162698
# C -2.249747 -0.147924  1.190617  0.195905  0.047981             -0.028979
# D -0.605244  0.872743  0.777672 -0.333161  0.539582             -0.290764
# E -0.709008  0.225959  0.135471  0.150424  0.376383              0.033990
#
#   Profession
# B    Student
# C    Teacher
# D   Engineer
# E     Doctor

# %%
print("\nSetting 'Profession' column as index\n",'-'*45, sep='')
print (df.set_index('Profession'))
# Out:
# Setting 'Profession' column as index
# ---------------------------------------------
#                    W         X         Y         Z       New  \
# Profession
# Student    -0.353145 -1.094828  3.705136 -0.148606 -1.243434
# Teacher    -2.249747 -0.147924  1.190617  0.195905  0.047981
# Engineer   -0.605244  0.872743  0.777672 -0.333161  0.539582
# Doctor     -0.709008  0.225959  0.135471  0.150424  0.376383
#
#             New (Sum of X and Z)
# Profession
# Student                 0.162698
# Teacher                -0.028979
# Engineer               -0.290764
# Doctor                  0.033990

# %%
df
# Out:
#           W         X         Y         Z       New  New (Sum of X and Z)  \
# B -0.353145 -1.094828  3.705136 -0.148606 -1.243434              0.162698
# C -2.249747 -0.147924  1.190617  0.195905  0.047981             -0.028979
# D -0.605244  0.872743  0.777672 -0.333161  0.539582             -0.290764
# E -0.709008  0.225959  0.135471  0.150424  0.376383              0.033990
#
#   Profession
# B    Student
# C    Teacher
# D   Engineer
# E     Doctor

# %%
#multi-indexing
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))

# %%
print("\nTuple pairs after the zip and list command\n",'-'*45, sep='')
print(hier_index)
# Out:
# Tuple pairs after the zip and list command
# ---------------------------------------------
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)
print("\nIndex hierarchy\n",'-'*25, sep='')
print(hier_index)
# Out:
# Index hierarchy
# -------------------------
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
print("\nIndex hierarchy type\n",'-'*25, sep='')
print(type(hier_index))
# Out:
# Index hierarchy type
# -------------------------
# <class 'pandas.core.indexes.multi.MultiIndex'>

# %%
print("\nCreating DataFrame with multi-index\n",'-'*37, sep='')
np.random.seed(101)
df1 = pd.DataFrame(data=np.round(rn(6,3)), index= hier_index, columns= ['A','B','C'])
print(df1)
# Out:
# Creating DataFrame with multi-index
# -------------------------------------
#         A    B    C
# G1 1  3.0  1.0  1.0
#    2  1.0  1.0 -0.0
#    3 -1.0  1.0 -2.0
# G2 1  1.0  1.0 -1.0
#    2  0.0 -1.0 -1.0
#    3  1.0  0.0  2.0

# %%
#cross tabulation like pivot table

# %%
print("\nGrabbing a cross-section from outer level\n",'-'*45, sep='')
print(df1.xs('G1'))
# Out:
# Grabbing a cross-section from outer level
# ---------------------------------------------
#      A    B    C
# 1 -0.0  1.0 -0.0
# 2  2.0 -1.0  0.0
# 3 -0.0 -0.0  1.0
